# %%
import pandas as pd

# %%
df = pd.read_csv("Bank Customer Churn Prediction.csv")

# %%
df
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619   France  Female   42       2       0.00
# 1        15647311           608    Spain  Female   41       1   83807.86
# 2        15619304           502   France  Female   42       8  159660.80
# 3        15701354           699   France  Female   39       1       0.00
# 4        15737888           850    Spain  Female   43       2  125510.82
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
df.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %%
df.tail()
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# 9995                2            1              0          96270.64      0
# 9996                1            1              1         101699.77      0
# 9997                1            0              1          42085.58      1
# 9998                2            1              0          92888.52      1
# 9999                1            1              0          38190.78      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %%
df.isnull()
# Out:
#       customer_id  credit_score  country  gender    age  tenure  balance  \
# 0           False         False    False   False  False   False    False
# 1           False         False    False   False  False   False    False
# 2           False         False    False   False  False   False    False
# 3           False         False    False   False  False   False    False
# 4           False         False    False   False  False   False    False
# ...           ...           ...      ...     ...    ...     ...      ...
# 9995        False         False    False   False  False   False    False
# 9996        False         False    False   False  False   False    False
# 9997        False         False    False   False  False   False    False
# 9998        False         False    False   False  False   False    False
# 9999        False         False    False   False  False   False    False
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
df.isnull().sum()
# Out:
# customer_id         0
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# products_number     0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'products_number', 'credit_card', 'active_member',
#        'estimated_salary', 'churn'],
#       dtype='object')

# %%
df.value_counts()
# Out:
# customer_id  credit_score  country  gender  age  tenure  balance    products_number  credit_card  active_member  estimated_salary  churn
# 15565701     698           Spain    Female  39   9       161993.89  1                0            0              90212.38          0        1
# 15732281     680           Germany  Male    34   6       146422.22  1                1            0              67142.97          1        1
# 15732199     837           Spain    Male    31   9       104678.62  1                0            1              50972.60          0        1
# 15732202     615           France   Male    34   1       83503.11   2                1            1              73124.53          1        1
# 15732235     662           France   Male    64   0       98848.19   1                0            1              42730.12          0        1
# ...

# %%
print("Unique Values in column country and gender are:")
for i in ['country','gender']:
    print(f"{i} : {df[i].unique()}")
# Out:
# Unique Values in column country and gender are:
# country : ['France' 'Spain' 'Germany']
# gender : ['Female' 'Male']

# %%
print("Count of Unique Values in column country and gender are:")
for i in ['country','gender']:
    print(f"{i} : {df[i].value_counts()}")
# Out:
# Count of Unique Values in column country and gender are:
# country : country
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64
# gender : gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
for i in ['churn']:
    print(f"{i} : {df[i].value_counts()}")
# Out:
# churn : churn
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.countplot(x='churn',data=df,palette="viridis")
plt.title('churn Prediction')
plt.show()
# Out:
# C:\Users\vishu_pdk4f5i\AppData\Local\Temp\ipykernel_5448\1051233627.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='churn',data=df,palette="viridis")

# %%
sns.countplot(x='churn',hue='gender',data=df,palette="bright")
plt.title('churn Prediction')
plt.show()

# %%
sns.countplot(x='gender',hue='churn',data=df,palette="viridis")
plt.title('churn Prediction')
plt.xlabel("female vs male Churn data Distribution")
plt.show()

# %%
df_encoded = pd.get_dummies(df)

correlation = df_encoded.corr()

# %%
correlation
# Out:
#                   customer_id  credit_score       age    tenure   balance  \
# customer_id          1.000000      0.005308  0.009497 -0.014883 -0.012419
# credit_score         0.005308      1.000000 -0.003965  0.000842  0.006268
# age                  0.009497     -0.003965  1.000000 -0.009997  0.028308
# tenure              -0.014883      0.000842 -0.009997  1.000000 -0.012254
# balance             -0.012419      0.006268  0.028308 -0.012254  1.000000
# products_number      0.016972      0.012238 -0.030680  0.013444 -0.304180
# credit_card         -0.014025     -0.005458 -0.011721  0.022583 -0.014858
# active_member        0.001665      0.025651  0.085472 -0.028362 -0.010084
# estimated_salary     0.015271     -0.001384 -0.007201  0.007784  0.012797
# churn               -0.006248     -0.027094  0.285323 -0.014001  0.118533
# country_France      -0.004049     -0.008928 -0.039208 -0.002848 -0.231329
# country_Germany     -0.003097      0.005538  0.046897 -0.000567  0.401110
# ...

# %%
plt.figure(figsize = (12,5))
sns.heatmap(correlation, annot = True, cmap = 'coolwarm',linewidths=0.5 )
plt.title("Correlation heat map")
plt.show()

# %%
#correlation helps in identifying the important predictors for the model and potential feature selection

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder

label = LabelEncoder()

df['country'] = label.fit_transform(df['country'])
df['gender'] = label.fit_transform(df['gender'])

# %%
df.head()
# Out:
#    customer_id  credit_score  country  gender  age  tenure    balance  \
# 0     15634602           619        0       0   42       2       0.00
# 1     15647311           608        2       0   41       1   83807.86
# 2     15619304           502        0       0   42       8  159660.80
# 3     15701354           699        0       0   39       1       0.00
# 4     15737888           850        2       0   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %%
df.drop(columns = ['customer_id'],inplace = True)

# %%
df.head()
# Out:
#    credit_score  country  gender  age  tenure    balance  products_number  \
# 0           619        0       0   42       2       0.00                1
# 1           608        2       0   41       1   83807.86                1
# 2           502        0       0   42       8  159660.80                3
# 3           699        0       0   39       1       0.00                2
# 4           850        2       0   43       2  125510.82                1
#
#    credit_card  active_member  estimated_salary  churn
# 0            1              1         101348.88      1
# 1            0              1         112542.58      0
# 2            1              0         113931.57      1
# 3            0              0          93826.63      0
# 4            1              1          79084.10      0

# %%
df.drop(columns = 'churn', axis = 1)
# Out:
#       credit_score  country  gender  age  tenure    balance  products_number  \
# 0              619        0       0   42       2       0.00                1
# 1              608        2       0   41       1   83807.86                1
# 2              502        0       0   42       8  159660.80                3
# 3              699        0       0   39       1       0.00                2
# 4              850        2       0   43       2  125510.82                1
# ...            ...      ...     ...  ...     ...        ...              ...
# 9995           771        0       1   39       5       0.00                2
# 9996           516        0       1   35      10   57369.61                1
# 9997           709        0       0   36       7       0.00                1
# 9998           772        1       1   42       3   75075.31                2
# 9999           792        0       0   28       4  130142.79                1
#
# ...

# %%
df.head()
# Out:
#    credit_score  country  gender  age  tenure    balance  products_number  \
# 0           619        0       0   42       2       0.00                1
# 1           608        2       0   41       1   83807.86                1
# 2           502        0       0   42       8  159660.80                3
# 3           699        0       0   39       1       0.00                2
# 4           850        2       0   43       2  125510.82                1
#
#    credit_card  active_member  estimated_salary  churn
# 0            1              1         101348.88      1
# 1            0              1         112542.58      0
# 2            1              0         113931.57      1
# 3            0              0          93826.63      0
# 4            1              1          79084.10      0

# %%
x = df.drop('churn',axis=1)

# %%
x
# Out:
#       credit_score  country  gender  age  tenure    balance  products_number  \
# 0              619        0       0   42       2       0.00                1
# 1              608        2       0   41       1   83807.86                1
# 2              502        0       0   42       8  159660.80                3
# 3              699        0       0   39       1       0.00                2
# 4              850        2       0   43       2  125510.82                1
# ...            ...      ...     ...  ...     ...        ...              ...
# 9995           771        0       1   39       5       0.00                2
# 9996           516        0       1   35      10   57369.61                1
# 9997           709        0       0   36       7       0.00                1
# 9998           772        1       1   42       3   75075.31                2
# 9999           792        0       0   28       4  130142.79                1
#
# ...

# %%
y = df['churn']

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: churn, Length: 10000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train , y_test = train_test_split(x,y,train_size = 0.8 , random_state = 1)

# %%
x_train
# Out:
#       credit_score  country  gender  age  tenure    balance  products_number  \
# 2694           628        1       1   29       3  113146.98                2
# 5140           626        0       0   29       4  105767.28                2
# 2568           612        1       0   47       6  130024.87                1
# 3671           646        1       0   52       6  111739.40                2
# 7427           714        2       1   33       8  122017.19                1
# ...            ...      ...     ...  ...     ...        ...              ...
# 2895           621        1       1   47       7  107363.29                1
# 7813           684        1       0   63       3   81245.79                1
# 905            672        0       0   45       9       0.00                1
# 5192           663        0       0   39       8       0.00                2
# 235            763        1       1   42       6  100160.75                1
#
# ...

# %%
scaler = StandardScaler()

# %%
x_train_scaled = scaler.fit_transform(x_train)

# %%
x_train_scaled
# Out:
# array([[-0.23082038,  0.30531046,  0.91509065, ..., -1.55337352,
#          0.97725852,  0.42739449],
#        [-0.25150912, -0.90503826, -1.09278791, ..., -1.55337352,
#         -1.02327069, -1.02548708],
#        [-0.3963303 ,  0.30531046, -1.09278791, ...,  0.64376017,
#          0.97725852, -0.94479772],
#        ...,
#        [ 0.22433188, -0.90503826, -1.09278791, ...,  0.64376017,
#          0.97725852, -0.14096853],
#        [ 0.13123255, -0.90503826, -1.09278791, ...,  0.64376017,
#          0.97725852,  0.01781218],
#        [ 1.1656695 ,  0.30531046,  0.91509065, ...,  0.64376017,
#         -1.02327069, -1.15822478]])

# %%
x_train_scaled = scaler.fit_transform(x_train)

# %%
x_train_scaled
# Out:
# array([[-0.23082038,  0.30531046,  0.91509065, ..., -1.55337352,
#          0.97725852,  0.42739449],
#        [-0.25150912, -0.90503826, -1.09278791, ..., -1.55337352,
#         -1.02327069, -1.02548708],
#        [-0.3963303 ,  0.30531046, -1.09278791, ...,  0.64376017,
#          0.97725852, -0.94479772],
#        ...,
#        [ 0.22433188, -0.90503826, -1.09278791, ...,  0.64376017,
#          0.97725852, -0.14096853],
#        [ 0.13123255, -0.90503826, -1.09278791, ...,  0.64376017,
#          0.97725852,  0.01781218],
#        [ 1.1656695 ,  0.30531046,  0.91509065, ...,  0.64376017,
#         -1.02327069, -1.15822478]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
logR = LogisticRegression()

# %%
logR.fit(x_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logR.predict(x_test)
# Out:
# C:\Users\vishu_pdk4f5i\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
y_pred = logR.predict(x_test_scaled)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
new_customer = [650, 1, 1, 25, 3, 10000, 2, 1, 1, 500000]

# %%
new_customer
# Out:
# [650, 1, 1, 25, 3, 10000, 2, 1, 1, 500000]

# %%
input_data = [new_customer]

# %%
input_data_scaled = scaler.transform(input_data)
# Out:
# C:\Users\vishu_pdk4f5i\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
input_data_scaled
# Out:
# array([[-3.24425289e-03,  3.05310465e-01,  9.15090654e-01,
#         -1.32660798e+00, -7.01742025e-01, -1.06565476e+00,
#          8.02256955e-01,  6.43760170e-01,  9.77258519e-01,
#          6.94541673e+00]])

# %%
predection = logR.predict(input_data_scaled)

# %%
predection
# Out:
# array([0], dtype=int64)
